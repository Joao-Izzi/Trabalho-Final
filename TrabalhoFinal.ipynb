# %%
import pandas as pd

# %%
df = pd.read_csv("dados.csv", sep = ",", index_col=0)
print(df.shape)
df.head(10)
# Out:
# (2100, 52)
#      feat_1    feat_2    feat_3    feat_4    feat_5    feat_6    feat_7  \
# 0  0.276295  1.294890  0.888687  1.763403  1.924051 -1.525458  0.736443
# 1  0.677212  0.185459  0.064948  0.073792  0.084700  0.282421  0.698945
# 2 -1.044824  0.310883  0.227623  0.594970  1.384309  1.307542  0.788633
# 3 -0.913868 -0.670931  0.119123 -2.052029 -1.431409  1.500219  0.038840
# 4  1.534146  1.599091  1.373254  0.225192  0.293527 -0.890291 -0.741208
# 5  0.866745 -1.029476 -0.587077  0.522505  2.015740  0.849283 -0.580701
# 6  0.167544  0.824305 -2.003820  0.379536  0.863169  1.525842  0.520568
# 7 -1.651540  0.168693  0.429007 -0.163278 -1.264337 -0.026900  0.672453
# 8 -0.608896 -0.985090  0.697248 -0.279475 -1.641565 -0.521428 -0.353245
# 9 -0.953363  0.402659 -0.390197 -0.408091  0.148451  0.496525 -1.201565
#
#      feat_8    feat_9   feat_10  ...   feat_43   feat_44   feat_45   feat_46  \
# 0  2.179009 -0.015214 -1.211330  ...  0.753638 -0.461635 -0.436963  0.617467
# ...
